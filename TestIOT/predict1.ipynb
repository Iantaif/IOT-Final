# %%
import pandas as pd

weather = pd.read_csv("data1.csv")

# %%
weather
# Out:
#            sensor Unnamed: 1   Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0            data        NaN          NaN             NaN        NaN
# 1  1/17/2024 7:36        NaN          NaN  1/17/2024 7:37        NaN
# 2        humidity       rain  temperature        humidity       rain
# 3              72          1         28.5              73          1
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7   Unnamed: 8      Unnamed: 9  ...  \
# 0          NaN             NaN        NaN          NaN             NaN  ...
# 1          NaN  1/17/2024 7:37        NaN          NaN  1/17/2024 7:37  ...
# 2  temperature        humidity       rain  temperature        humidity  ...
# 3         28.5              73          1         28.5              73  ...
#
#   Unnamed: 991    Unnamed: 992 Unnamed: 993 Unnamed: 994    Unnamed: 995  \
# 0          NaN             NaN          NaN          NaN             NaN
# 1          NaN  1/17/2024 8:04          NaN          NaN  1/17/2024 8:04
# ...
